# %%
import os
from glob import glob 
import time
import random
from datetime import datetime

import timm
import torch
import albumentations as A
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch.nn as nn
from albumentations.pytorch import ToTensorV2
from torch.optim import Adam
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from tqdm import tqdm
from sklearn.metrics import accuracy_score, f1_score
import cv2

import matplotlib.pyplot as plt
import seaborn as sns

import wandb

# %%
def random_seed(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = True

random_seed(42)

# %%
# device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# data config
train_data_path = '../data2/train/'
test_data_path = '../data2/test/'

# model config
model_name = 'efficientnet_b4' #resnet50' 'efficientnet-b0', ...

# training config
img_size = 224
LR = 1e-3
EPOCHS = 20
BATCH_SIZE = 64
num_workers = 0
log_interval = 370

# %%
# 데이터셋 클래스를 정의합니다.
class ImageDataset(Dataset):
    def __init__(self, data_path, ids, targets=None, transform=None):
        self.ids = ids
        self.targets = targets
        self.data_path = data_path
        self.transform = transform 

    def __len__(self):
        return len(self.ids)

    def __getitem__(self, idx):
        ID = self.ids[idx]
        image_path = os.path.join(self.data_path, ID)
        img = np.array(Image.open(image_path))
        if self.transform:
            img = self.transform(image=img)['image']
        if self.targets is not None:
            return img, self.targets[idx]
        else:
            return img

# %%
def mixup_data(x, y, alpha=1.0):
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size)
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam

def mixup_loss(loss_fn, pred, labels_a, labels_b, lam):
    return lam * loss_fn(pred, labels_a) + (1 - lam) * loss_fn(pred, labels_b)

# %%
def train_per_epoch(epoch, model, train_loader, loss_fn, optimizer, train_step):
    preds_list = []
    labels_list = []

    for batch_idx, (images, labels) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)

        current_loss = 0.0

        if (batch_idx + 1) % 5 == 0:
            imgs, labels_a, labels_b, lambda_ = mixup_data(images, labels)
            output = model(imgs)
            loss = mixup_loss(loss_fn=loss_fn, pred=output, labels_a=labels_a, labels_b=labels_b, lam=lambda_)
        else: 
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            loss = loss_fn(outputs, labels)

            preds_list.extend(preds.detach().cpu().numpy())
            labels_list.extend(labels.detach().cpu().numpy())

        # Back propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        current_loss += loss.item()

        if (batch_idx + 1) % log_interval == 0:
            train_loss = current_loss / log_interval
            train_acc = accuracy_score(labels_list, preds_list)
            train_f1 = f1_score(labels_list, preds_list, average='macro')

            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}, Train Acc: {:.4f}, Train F1 Score: {:.4f}".format(
                epoch, 
                batch_idx * len(images), 
                len(train_loader) * len(images), 
                100 * batch_idx / len(train_loader), 
                train_loss, 
                train_acc,
                train_f1))

            if wandb is not None:
                wandb.log({
                    "Loss/Train": train_loss,
                    "Accuracy/Train": train_acc,
                    "F1 Score/Train": train_f1,
                    "Image/Train": wandb.Image(images),
                    "Output/Train": wandb.Histogram(outputs.detach().cpu().numpy()),
                    "Preds/Train": wandb.Histogram(preds.detach().cpu().numpy()),
                    "Labels/Train": wandb.Histogram(labels.detach().cpu().numpy()),  
                }, step=train_step)
        train_step += 1

    return train_step, current_loss / len(train_loader), accuracy_score(labels_list, preds_list), f1_score(labels_list, preds_list, average='macro')
    
def validation(model, val_loader, loss_fn, train_step):
    val_preds_list = []
    val_labels_list = []
    with torch.no_grad():
        val_loss = 0.0
        model.eval()

        for val_idx, (val_images, val_labels) in enumerate(val_loader):
            val_images, val_labels = val_images.to(device), val_labels.to(device)

            val_outputs = model(val_images)
            _, val_preds = torch.max(val_outputs, 1)

            val_loss += loss_fn(val_outputs, val_labels) / val_outputs.shape[0]
            
            val_preds_list.extend(val_preds.detach().cpu().numpy())
            val_labels_list.extend(val_labels.detach().cpu().numpy())

        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_acc = accuracy_score(val_labels_list, val_preds_list)
        val_epoch_f1 = f1_score(val_labels_list, val_preds_list, average='macro')

        if wandb is not None:
            wandb.log({
                "Loss/Val": val_epoch_loss,
                "Accuracy/Val": val_epoch_acc,
                "F1 Score/Val": val_epoch_f1,
                "Image/Val": wandb.Image(val_images),
                "Output/Val": wandb.Histogram(val_outputs.detach().cpu().numpy()),
                "Preds/Val": wandb.Histogram(val_preds.detach().cpu().numpy()),
                "Labels/Val": wandb.Histogram(val_labels.detach().cpu().numpy()),  
            }, step=train_step )

        print("Validation dataset: Val Loss: {:.6f}, Val Acc: {:.4f}, Val F1 Score: {:.4f}".format(val_epoch_loss, val_epoch_acc, val_epoch_f1))
    return val_epoch_loss, val_epoch_acc, val_epoch_f1

# %%
df = pd.read_csv('../data2/add_transformed_train.csv')
sample_submission_df = pd.read_csv("../data2/sample_submission.csv")

# %%
df_train, df_val = train_test_split(df, test_size=0.2, shuffle=True, random_state=42)
print(len(df_train), len(df_val))
# Out:
# 118387 29597

# %%
train_transform = A.Compose([
    # 이미지 크기 조정
    A.Resize(height=img_size, width=img_size),
    # images normalization
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    # numpy 이미지나 PIL 이미지를 PyTorch 텐서로 변환
    ToTensorV2(),
])

# test image 변환을 위한 transform 코드
valid_transform = A.Compose([
    A.Resize(height=img_size, width=img_size),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
])

test_transform = A.Compose([
    A.Resize(height=img_size, width=img_size),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ToTensorV2(),
])

# %%
# Dataset 정의
train_dataset = ImageDataset(
    train_data_path,
    df_train['ID'].values,
    df_train['target'].values,
    transform=train_transform
)
valid_dataset = ImageDataset(
    train_data_path,
    df_val['ID'].values,
    df_val['target'].values,
    transform=valid_transform
)
test_dataset = ImageDataset(
    test_data_path,
    sample_submission_df['ID'].values,
    transform=test_transform
)
print(len(train_dataset), len(valid_dataset), len(test_dataset))
# Out:
# 118387 29597 3140

# %%
# DataLoader 정의
train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=num_workers,
    pin_memory=True,
    drop_last=False
)
valid_loader = DataLoader(
    valid_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)
test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)

# %%
class_weights = torch.tensor([1.0, 1.0, 1.0, 3.0, 1.0, 1.0, 1.0, 3.0, 1.0, 1.0, 1.0, 1.0, 2.0, 1.0, 1.0, 1.0, 1.0]).to(device)

# %%
model = timm.create_model(
    model_name,
    pretrained=True,
    num_classes=17
).to(device)
loss_fn = nn.CrossEntropyLoss(weight=class_weights)
optimizer = Adam(model.parameters(), lr=LR)
optimizer_name = type(optimizer).__name__

run_name = f"{datetime.now().isoformat(timespec='seconds')}-{model_name}-{optimizer_name}_optim-{LR}_lr_using_class-weights"
log_dir = f"runs/{run_name}"

project_name = 'DTC-ch'
run_tags=[project_name]
wandb.init(
    project=project_name,
    name=run_name,
    tags=run_tags,
    config={"lr": LR, "model_name": model_name, "optimizer_name": optimizer_name},
    reinit=True
)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: ch_hee (aistages-cv-04). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/data/ephemeral/home/code/wandb/run-20240213_004750-jquvtr95</code>
# Syncing run <strong><a href='https://wandb.ai/aistages-cv-04/DTC-ch/runs/jquvtr95' target="_blank">2024-02-13T00:47:49-efficientnet_b4-Adam_optim-0.001_lr_using_class-weights</a></strong> to <a href='https://wandb.ai/aistages-cv-04/DTC-ch' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/aistages-cv-04/DTC-ch' target="_blank">https://wandb.ai/aistages-cv-04/DTC-ch</a>
#  View run at <a href='https://wandb.ai/aistages-cv-04/DTC-ch/runs/jquvtr95' target="_blank">https://wandb.ai/aistages-cv-04/DTC-ch/runs/jquvtr95</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/aistages-cv-04/DTC-ch/runs/jquvtr95?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
log_dir = f"runs/{datetime.now().isoformat(timespec='seconds')}-{model_name}"
model_path = os.path.join(log_dir, 'models')
os.makedirs(model_path, exist_ok=True)

# %%
save_point = 0
path = os.path.join(model_path, 'model.ckpt')

train_result = []
val_result = []

train_step = 0
for epoch in range(1, EPOCHS + 1):
    train_step, train_loss, train_acc, train_f1 = train_per_epoch(epoch, model, train_loader, loss_fn, optimizer, train_step)
    val_loss, val_acc, val_f1 = validation(model, valid_loader, loss_fn, train_step)
    train_result.append([train_loss, train_acc, train_f1])
    val_result.append([val_loss, val_acc, val_f1])

    if val_f1 > save_point:
        save_point = val_f1
        save_dir = os.path.dirname(path)
        torch.save(model, os.path.join(save_dir, f'val_f1-{val_f1}-{path.split("/")[-1]}'))
        print('Saved Model!!!')
# Out:
# Train Epoch: 1 [0/118400 (0%)]	Train Loss: 0.008463, Train Acc: 0.0312, Train F1 Score: 0.0275
# Train Epoch: 1 [23680/118400 (20%)]	Train Loss: 0.000589, Train Acc: 0.8343, Train F1 Score: 0.8381
# Train Epoch: 1 [47360/118400 (40%)]	Train Loss: 0.000288, Train Acc: 0.8948, Train F1 Score: 0.8971
# Train Epoch: 1 [71040/118400 (60%)]	Train Loss: 0.000066, Train Acc: 0.9207, Train F1 Score: 0.9221
# Train Epoch: 1 [94720/118400 (80%)]	Train Loss: 0.000306, Train Acc: 0.9362, Train F1 Score: 0.9372
# Validation dataset: Val Loss: 0.000776, Val Acc: 0.9863, Val F1 Score: 0.9863
# Saved Model!!!
# Train Epoch: 2 [0/118400 (0%)]	Train Loss: 0.000276, Train Acc: 0.9688, Train F1 Score: 0.9636
# Train Epoch: 2 [23680/118400 (20%)]	Train Loss: 0.000563, Train Acc: 0.9608, Train F1 Score: 0.9609
# Train Epoch: 2 [47360/118400 (40%)]	Train Loss: 0.000048, Train Acc: 0.9722, Train F1 Score: 0.9724
# Train Epoch: 2 [71040/118400 (60%)]	Train Loss: 0.000077, Train Acc: 0.9768, Train F1 Score: 0.9769
# Train Epoch: 2 [94720/118400 (80%)]	Train Loss: 0.000129, Train Acc: 0.9802, Train F1 Score: 0.9803
# Validation dataset: Val Loss: 0.000996, Val Acc: 0.9875, Val F1 Score: 0.9874
# Saved Model!!!
# Train Epoch: 3 [0/118400 (0%)]	Train Loss: 0.000032, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 3 [23680/118400 (20%)]	Train Loss: 0.000067, Train Acc: 0.9938, Train F1 Score: 0.9938
# Train Epoch: 3 [47360/118400 (40%)]	Train Loss: 0.000001, Train Acc: 0.9935, Train F1 Score: 0.9936
# Train Epoch: 3 [71040/118400 (60%)]	Train Loss: 0.000012, Train Acc: 0.9935, Train F1 Score: 0.9935
# Train Epoch: 3 [94720/118400 (80%)]	Train Loss: 0.000100, Train Acc: 0.9927, Train F1 Score: 0.9927
# Validation dataset: Val Loss: 0.000504, Val Acc: 0.9934, Val F1 Score: 0.9934
# Saved Model!!!
# Train Epoch: 4 [0/118400 (0%)]	Train Loss: 0.000010, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 4 [23680/118400 (20%)]	Train Loss: 0.000004, Train Acc: 0.9952, Train F1 Score: 0.9952
# Train Epoch: 4 [47360/118400 (40%)]	Train Loss: 0.000031, Train Acc: 0.9943, Train F1 Score: 0.9944
# Train Epoch: 4 [71040/118400 (60%)]	Train Loss: 0.000054, Train Acc: 0.9947, Train F1 Score: 0.9947
# Train Epoch: 4 [94720/118400 (80%)]	Train Loss: 0.000032, Train Acc: 0.9944, Train F1 Score: 0.9944
# Validation dataset: Val Loss: 0.000828, Val Acc: 0.9904, Val F1 Score: 0.9904
# Train Epoch: 5 [0/118400 (0%)]	Train Loss: 0.000032, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 5 [23680/118400 (20%)]	Train Loss: 0.000013, Train Acc: 0.9963, Train F1 Score: 0.9963
# Train Epoch: 5 [47360/118400 (40%)]	Train Loss: 0.000004, Train Acc: 0.9948, Train F1 Score: 0.9947
# Train Epoch: 5 [71040/118400 (60%)]	Train Loss: 0.000016, Train Acc: 0.9953, Train F1 Score: 0.9952
# Train Epoch: 5 [94720/118400 (80%)]	Train Loss: 0.000006, Train Acc: 0.9952, Train F1 Score: 0.9952
# Validation dataset: Val Loss: 0.000430, Val Acc: 0.9930, Val F1 Score: 0.9930
# Train Epoch: 6 [0/118400 (0%)]	Train Loss: 0.000027, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 6 [23680/118400 (20%)]	Train Loss: 0.000030, Train Acc: 0.9978, Train F1 Score: 0.9979
# Train Epoch: 6 [47360/118400 (40%)]	Train Loss: 0.000005, Train Acc: 0.9974, Train F1 Score: 0.9974
# Train Epoch: 6 [71040/118400 (60%)]	Train Loss: 0.000013, Train Acc: 0.9977, Train F1 Score: 0.9977
# Train Epoch: 6 [94720/118400 (80%)]	Train Loss: 0.000013, Train Acc: 0.9972, Train F1 Score: 0.9971
# Validation dataset: Val Loss: 0.000332, Val Acc: 0.9953, Val F1 Score: 0.9953
# Saved Model!!!
# Train Epoch: 7 [0/118400 (0%)]	Train Loss: 0.000005, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 7 [23680/118400 (20%)]	Train Loss: 0.000039, Train Acc: 0.9943, Train F1 Score: 0.9943
# Train Epoch: 7 [47360/118400 (40%)]	Train Loss: 0.000017, Train Acc: 0.9954, Train F1 Score: 0.9954
# Train Epoch: 7 [71040/118400 (60%)]	Train Loss: 0.000035, Train Acc: 0.9953, Train F1 Score: 0.9953
# Train Epoch: 7 [94720/118400 (80%)]	Train Loss: 0.000010, Train Acc: 0.9955, Train F1 Score: 0.9955
# Validation dataset: Val Loss: 0.000432, Val Acc: 0.9945, Val F1 Score: 0.9945
# Train Epoch: 8 [0/118400 (0%)]	Train Loss: 0.000008, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 8 [23680/118400 (20%)]	Train Loss: 0.000002, Train Acc: 0.9982, Train F1 Score: 0.9982
# Train Epoch: 8 [47360/118400 (40%)]	Train Loss: 0.000024, Train Acc: 0.9979, Train F1 Score: 0.9979
# Train Epoch: 8 [71040/118400 (60%)]	Train Loss: 0.000016, Train Acc: 0.9967, Train F1 Score: 0.9967
# Train Epoch: 8 [94720/118400 (80%)]	Train Loss: 0.000027, Train Acc: 0.9970, Train F1 Score: 0.9970
# Validation dataset: Val Loss: 0.000364, Val Acc: 0.9958, Val F1 Score: 0.9958
# Saved Model!!!
# Train Epoch: 9 [0/118400 (0%)]	Train Loss: 0.000010, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 9 [23680/118400 (20%)]	Train Loss: 0.000032, Train Acc: 0.9955, Train F1 Score: 0.9954
# Train Epoch: 9 [47360/118400 (40%)]	Train Loss: 0.000002, Train Acc: 0.9969, Train F1 Score: 0.9969
# Train Epoch: 9 [71040/118400 (60%)]	Train Loss: 0.000017, Train Acc: 0.9958, Train F1 Score: 0.9958
# Train Epoch: 9 [94720/118400 (80%)]	Train Loss: 0.000012, Train Acc: 0.9959, Train F1 Score: 0.9959
# Validation dataset: Val Loss: 0.000309, Val Acc: 0.9960, Val F1 Score: 0.9960
# Saved Model!!!
# Train Epoch: 10 [0/118400 (0%)]	Train Loss: 0.000087, Train Acc: 0.9844, Train F1 Score: 0.9750
# Train Epoch: 10 [23680/118400 (20%)]	Train Loss: 0.000019, Train Acc: 0.9980, Train F1 Score: 0.9980
# Train Epoch: 10 [47360/118400 (40%)]	Train Loss: 0.000002, Train Acc: 0.9981, Train F1 Score: 0.9981
# Train Epoch: 10 [71040/118400 (60%)]	Train Loss: 0.000001, Train Acc: 0.9980, Train F1 Score: 0.9980
# Train Epoch: 10 [94720/118400 (80%)]	Train Loss: 0.000015, Train Acc: 0.9979, Train F1 Score: 0.9979
# Validation dataset: Val Loss: 0.000367, Val Acc: 0.9953, Val F1 Score: 0.9953
# Train Epoch: 11 [0/118400 (0%)]	Train Loss: 0.000005, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 11 [23680/118400 (20%)]	Train Loss: 0.000001, Train Acc: 0.9989, Train F1 Score: 0.9989
# Train Epoch: 11 [47360/118400 (40%)]	Train Loss: 0.000018, Train Acc: 0.9986, Train F1 Score: 0.9986
# Train Epoch: 11 [71040/118400 (60%)]	Train Loss: 0.000004, Train Acc: 0.9968, Train F1 Score: 0.9968
# Train Epoch: 11 [94720/118400 (80%)]	Train Loss: 0.000005, Train Acc: 0.9972, Train F1 Score: 0.9972
# Validation dataset: Val Loss: 0.001349, Val Acc: 0.9850, Val F1 Score: 0.9849
# Train Epoch: 12 [0/118400 (0%)]	Train Loss: 0.000184, Train Acc: 0.9688, Train F1 Score: 0.9589
# Train Epoch: 12 [23680/118400 (20%)]	Train Loss: 0.000001, Train Acc: 0.9960, Train F1 Score: 0.9960
# Train Epoch: 12 [47360/118400 (40%)]	Train Loss: 0.000139, Train Acc: 0.9967, Train F1 Score: 0.9967
# Train Epoch: 12 [71040/118400 (60%)]	Train Loss: 0.000130, Train Acc: 0.9972, Train F1 Score: 0.9972
# Train Epoch: 12 [94720/118400 (80%)]	Train Loss: 0.000014, Train Acc: 0.9964, Train F1 Score: 0.9964
# Validation dataset: Val Loss: 0.000240, Val Acc: 0.9964, Val F1 Score: 0.9964
# Saved Model!!!
# Train Epoch: 13 [0/118400 (0%)]	Train Loss: 0.000011, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 13 [23680/118400 (20%)]	Train Loss: 0.000037, Train Acc: 0.9989, Train F1 Score: 0.9989
# Train Epoch: 13 [47360/118400 (40%)]	Train Loss: 0.000006, Train Acc: 0.9988, Train F1 Score: 0.9988
# Train Epoch: 13 [71040/118400 (60%)]	Train Loss: 0.000003, Train Acc: 0.9987, Train F1 Score: 0.9987
# Train Epoch: 13 [94720/118400 (80%)]	Train Loss: 0.000005, Train Acc: 0.9979, Train F1 Score: 0.9979
# Validation dataset: Val Loss: 0.000244, Val Acc: 0.9970, Val F1 Score: 0.9970
# Saved Model!!!
# Train Epoch: 14 [0/118400 (0%)]	Train Loss: 0.000011, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 14 [23680/118400 (20%)]	Train Loss: 0.000003, Train Acc: 0.9982, Train F1 Score: 0.9982
# Train Epoch: 14 [47360/118400 (40%)]	Train Loss: 0.000012, Train Acc: 0.9986, Train F1 Score: 0.9985
# Train Epoch: 14 [71040/118400 (60%)]	Train Loss: 0.000001, Train Acc: 0.9988, Train F1 Score: 0.9988
# Train Epoch: 14 [94720/118400 (80%)]	Train Loss: 0.000006, Train Acc: 0.9987, Train F1 Score: 0.9987
# Validation dataset: Val Loss: 0.000416, Val Acc: 0.9953, Val F1 Score: 0.9952
# Train Epoch: 15 [0/118400 (0%)]	Train Loss: 0.000002, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 15 [23680/118400 (20%)]	Train Loss: 0.000005, Train Acc: 0.9987, Train F1 Score: 0.9987
# Train Epoch: 15 [47360/118400 (40%)]	Train Loss: 0.000035, Train Acc: 0.9977, Train F1 Score: 0.9977
# Train Epoch: 15 [71040/118400 (60%)]	Train Loss: 0.000040, Train Acc: 0.9967, Train F1 Score: 0.9967
# Train Epoch: 15 [94720/118400 (80%)]	Train Loss: 0.000003, Train Acc: 0.9971, Train F1 Score: 0.9971
# Validation dataset: Val Loss: 0.000301, Val Acc: 0.9950, Val F1 Score: 0.9949
# Train Epoch: 16 [0/118400 (0%)]	Train Loss: 0.000005, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 16 [23680/118400 (20%)]	Train Loss: 0.000006, Train Acc: 0.9988, Train F1 Score: 0.9988
# Train Epoch: 16 [47360/118400 (40%)]	Train Loss: 0.000004, Train Acc: 0.9985, Train F1 Score: 0.9985
# Train Epoch: 16 [71040/118400 (60%)]	Train Loss: 0.000072, Train Acc: 0.9981, Train F1 Score: 0.9981
# Train Epoch: 16 [94720/118400 (80%)]	Train Loss: 0.000088, Train Acc: 0.9968, Train F1 Score: 0.9968
# Validation dataset: Val Loss: 0.000241, Val Acc: 0.9971, Val F1 Score: 0.9971
# Saved Model!!!
# Train Epoch: 17 [0/118400 (0%)]	Train Loss: 0.000007, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 17 [23680/118400 (20%)]	Train Loss: 0.000005, Train Acc: 0.9990, Train F1 Score: 0.9990
# Train Epoch: 17 [47360/118400 (40%)]	Train Loss: 0.000059, Train Acc: 0.9989, Train F1 Score: 0.9989
# Train Epoch: 17 [71040/118400 (60%)]	Train Loss: 0.000006, Train Acc: 0.9983, Train F1 Score: 0.9983
# Train Epoch: 17 [94720/118400 (80%)]	Train Loss: 0.000050, Train Acc: 0.9984, Train F1 Score: 0.9984
# Validation dataset: Val Loss: 0.000131, Val Acc: 0.9981, Val F1 Score: 0.9981
# Saved Model!!!
# Train Epoch: 18 [0/118400 (0%)]	Train Loss: 0.000006, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 18 [23680/118400 (20%)]	Train Loss: 0.000001, Train Acc: 0.9987, Train F1 Score: 0.9987
# Train Epoch: 18 [47360/118400 (40%)]	Train Loss: 0.000022, Train Acc: 0.9986, Train F1 Score: 0.9986
# Train Epoch: 18 [71040/118400 (60%)]	Train Loss: 0.000009, Train Acc: 0.9988, Train F1 Score: 0.9988
# Train Epoch: 18 [94720/118400 (80%)]	Train Loss: 0.000014, Train Acc: 0.9979, Train F1 Score: 0.9979
# Validation dataset: Val Loss: 0.000387, Val Acc: 0.9966, Val F1 Score: 0.9966
# Train Epoch: 19 [0/118400 (0%)]	Train Loss: 0.000021, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 19 [23680/118400 (20%)]	Train Loss: 0.000002, Train Acc: 0.9989, Train F1 Score: 0.9989
# Train Epoch: 19 [47360/118400 (40%)]	Train Loss: 0.000005, Train Acc: 0.9992, Train F1 Score: 0.9992
# Train Epoch: 19 [71040/118400 (60%)]	Train Loss: 0.000012, Train Acc: 0.9991, Train F1 Score: 0.9991
# Train Epoch: 19 [94720/118400 (80%)]	Train Loss: 0.000002, Train Acc: 0.9986, Train F1 Score: 0.9986
# Validation dataset: Val Loss: 0.000166, Val Acc: 0.9977, Val F1 Score: 0.9977
# Train Epoch: 20 [0/118400 (0%)]	Train Loss: 0.000002, Train Acc: 1.0000, Train F1 Score: 1.0000
# Train Epoch: 20 [23680/118400 (20%)]	Train Loss: 0.000002, Train Acc: 0.9991, Train F1 Score: 0.9991
# Train Epoch: 20 [47360/118400 (40%)]	Train Loss: 0.000002, Train Acc: 0.9985, Train F1 Score: 0.9985
# Train Epoch: 20 [71040/118400 (60%)]	Train Loss: 0.000002, Train Acc: 0.9985, Train F1 Score: 0.9985
# Train Epoch: 20 [94720/118400 (80%)]	Train Loss: 0.000004, Train Acc: 0.9985, Train F1 Score: 0.9985
# Validation dataset: Val Loss: 0.000333, Val Acc: 0.9967, Val F1 Score: 0.9967

# %%
best_model = torch.load('../code/runs/2024-02-13T00:47:56-efficientnet_b4/models/val_f1-0.9981251965560252-model.ckpt')

# %%
# for valid
val_preds_list = []
val_targets_list = []

with torch.no_grad():
    val_loss = 0.0
    val_correct = 0.0
    best_model.eval()

    for val_idx, (val_images, val_labels) in enumerate(valid_loader):
        val_images, val_labels = val_images.to(device), val_labels.to(device)

        val_outputs = best_model(val_images)
        _, val_preds = torch.max(val_outputs, 1)
        
        val_preds_list.extend(val_preds.detach().cpu().numpy())
        val_targets_list.extend(val_labels.detach().cpu().numpy())

# %%
accuracy_score(val_targets_list, val_preds_list)
# Out:
# 0.9981417035510356

# %%
df_val['pred'] = val_preds_list

# %%
df_val[df_val['target'] == df_val['pred']].target.count()
# Out:
# 29542

# %%
df_val[df_val['target'] != df_val['pred']].target.value_counts()
# Out:
# target
# 14    26
# 4      9
# 3      7
# 7      5
# 13     2
# 8      2
# 10     1
# 1      1
# 12     1
# 11     1
# Name: count, dtype: int64

# %%
df_val[df_val['target'] != df_val['pred']].iloc[10:20]
# Out:
#                                          ID  target  pred
# 14643             tf11_1ec14a14bbe633db.jpg      14     7
# 35750         tf6_r270_1ec14a14bbe633db.jpg      14     7
# 139345  tf5_Hflip_r180_d17e596e8baca59b.jpg      14     4
# 117130  tf10_Vflip_r90_60736fb522fa9311.jpg      13     1
# 40097         tf2_r180_3696b2ffaa6147e6.jpg      14     3
# 56892        tf12_r180_8345196de286a646.jpg      14     7
# 61380          tf8_r90_9d380d37a3c5e37d.jpg       3     7
# 103438  tf2_Hflip_r180_1ec14a14bbe633db.jpg      14     7
# 27084              tf4_d87fe6344741e8e4.jpg       7     3
# 47393         tf8_r270_57b5968d4c045943.jpg      12    10

# %%
Image.open('../data2/train/tf5_Hflip_r180_d17e596e8baca59b.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=443x591>

# %%
Image.open('../data2/train/r90_5249ba4981645813.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=591x443>

# %%
preds_list = []

best_model.eval()
for image in tqdm(test_loader):
    image = image.to(device)

    with torch.no_grad():
        preds = best_model(image)
    preds_list.extend(preds.argmax(dim=1).detach().cpu().numpy())
# Out:
# 100%|██████████| 50/50 [00:15<00:00,  3.24it/s]

# %%
assert (sample_submission_df['ID'] == test_dataset.ids).all()

# %%
pred_df = pd.DataFrame(test_dataset.ids, columns=['ID'])
pred_df['target'] = preds_list

# %%
pred_df.to_csv("pred7.csv", index=False)

# %%
# !pwd
# Out:
# /data/ephemeral/home/code

# %%
pred3 = pd.read_csv('../code/pred3.csv')
pred4 = pd.read_csv('../code/pred7.csv')
temp = pred3.merge(pred4, how='left', on=['ID'])

# %%
temp[temp['target_x'] != temp['target_y']].head(30)
# Out:
#                        ID  target_x  target_y
# 16   0145dd3d1cd090ae.jpg         4        14
# 26   020740b55bbc329e.jpg        14         3
# 30   02b370d53ff25d45.jpg         3        12
# 49   04fc58802ef2f7a6.jpg         3        14
# 70   071a06f75055347b.jpg         4        14
# 74   075ed6e4c487debc.jpg        14         7
# 83   082e8c4d8d82eb01.jpg         7         3
# 94   09194a475da4ddcc.jpg         3         7
# 101  099398ecd1bcf6bd.jpg         7         3
# 128  0b848234702391ca.jpg         7         3
# 142  0ca4d10967304b77.jpg        14         3
# 178  1024f408d288354b.jpg         7         3
# 191  10b951d45cab812b.jpg         0         7
# 217  12c0ac56836761e0.jpg         3         7
# 251  15ca73556389df7e.jpg         7         3
# 256  15efe59b41f3ccc7.jpg         7         4
# 267  17708afd7660980a.jpg         3         7
# 271  17ab20ba9372dfc0.jpg         7         3
# 282  189255f6ac4eb66b.jpg         3         7
# 293  19715393750c278b.jpg        14         7
# 297  1a0ba37806171e85.jpg         4         7
# 310  1b45268518d29b07.jpg         7         3
# 314  1b8e376917bc35ce.jpg         7         3
# 360  1f5f0b704c5daf78.jpg         3         7
# 365  1fbe8682aec6fe42.jpg         4         7
# 377  20c4d87dd513d951.jpg         3         7
# 383  2151ee0c994c9423.jpg         3         7
# 431  258e073a7f65a0a6.jpg         4         7
# 438  266278ebc9732a80.jpg         3         7
# 461  285481c6e36c45c1.jpg         4         7

# %%
Image.open('../data2/test/0ca4d10967304b77.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=591x443>
