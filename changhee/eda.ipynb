# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from PIL import Image
import os 
from glob import glob

# %%
data_path = '../data2/train/'
df = pd.read_csv('../data2/train.csv')
df
# Out:
#                         ID  target
# 0     002f99746285dfdd.jpg      16
# 1     008ccd231e1fea5d.jpg      10
# 2     008f5911bfda7695.jpg      10
# 3     009235e4c9c07af5.jpg       4
# 4     00b2f44967580c74.jpg      16
# ...                    ...     ...
# 1565  fed9e9ec4a77bc06.jpg       4
# 1566  feeade617aa68c45.jpg       7
# 1567  ff51dd281a8423f1.jpg      11
# 1568  ff8a6a251ce51c95.jpg       5
# 1569  ffc22136f958deb1.jpg       9
#
# [1570 rows x 2 columns]

# %%
index = 66
temp = df[df['target'] == 7]

# %%
ID
# Out:
# '8646f2c3280a4f49.jpg'

# %%
index
# Out:
# 68

# %%
ID = temp.ID.values[index]
display(Image.open(os.path.join(data_path, ID)))
index += 1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=443x591>

# %%
Image.open(np.random.choice(glob('../data2/test/*')))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=432x606>
